# %% [markdown]
# # assignment probability and statistics

# %% [markdown]
# # qsn 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# Load dataset
def load_dataset(file_path):
  return pd.read_csv(file_path)

df = load_dataset("./iris.csv")
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# computing means ...
mean_sepalLength = np.mean(df['sepal_length'])
mean_sepalWidth = np.mean(df['sepal_width'])
mean_petalLength = np.mean(df['petal_length'])
mean_petalWidth = np.mean(df['petal_width'])

# Printing means ...
print("Mean Sepal_Length = ",round(mean_sepalLength,4))
print("Mean Sepal_Width = ",round(mean_sepalWidth,4))
print("Mean Petal_Length = ",round(mean_petalLength,4))
print("Mean Petal_Width = ",round(mean_petalWidth,4))

# computing medians ...
median_sepalLength = np.median(df['sepal_length'])
median_sepalWidth = np.median(df['sepal_width'])
median_petalLength = np.median(df['petal_length'])
median_petalWidth = np.median(df['petal_width'])

print("\n")

# Printing medians ...
print("Median Sepal_Length = ",round(median_sepalLength,4))
print("Median Sepal_Width = ",round(median_sepalWidth,4))
print("Median Petal_Length = ",round(median_petalLength,4))
print("Median Petal_Width = ",round(median_petalWidth,4))

# computing standard deviation ...
std_sepalLength = np.std(df['sepal_length'])
std_sepalWidth = np.std(df['sepal_width'])
std_petalLength = np.std(df['petal_length'])
std_petalWidth = np.std(df['petal_width'])

print("\n")
# Printing standard deviation ...
print("Standard Deviation Sepal_Length = ",round(std_sepalLength,4))
print("Standard Deviation Sepal_Width = ",round(std_sepalWidth,4))
print("Standard Deviation Petal_Length = ",round(std_petalLength,4))
print("Standard Deviation Petal_Width = ",round(std_petalWidth,4))
# Out:
# Mean Sepal_Length =  5.8433
# Mean Sepal_Width =  3.054
# Mean Petal_Length =  3.7587
# Mean Petal_Width =  1.1987
#
#
# Median Sepal_Length =  5.8
# Median Sepal_Width =  3.0
# Median Petal_Length =  4.35
# Median Petal_Width =  1.3
#
#
# Standard Deviation Sepal_Length =  0.8253
# Standard Deviation Sepal_Width =  0.4321
# Standard Deviation Petal_Length =  1.7585
# Standard Deviation Petal_Width =  0.7606

# %%
# Plots ...
# boxplot  ...
sns.boxplot(df['sepal_length'],
            showmeans= True,
            color= 'b',
            meanprops = {
                "marker" : "+",
                "markeredgecolor" : "white",
                "markersize" : '10'
                }
            )
plt.ylabel('Length')
plt.xlabel('sepal')
plt.show()

sns.boxplot(df['sepal_width'],
            showmeans= True,
            color= 'g',
            meanprops = {
                "marker" : "+",
                "markeredgecolor" : "white",
                "markersize" : '10'
                }
            )
plt.ylabel('Width')
plt.xlabel('sepal')
plt.show()

sns.boxplot(df['petal_length'],
            showmeans= True,
            color= 'r',
            meanprops = {
                "marker" : "+",
                "markeredgecolor" : "white",
                "markersize" : '10'
                }
            )
plt.ylabel('Length')
plt.xlabel('Petal')
plt.show()
sns.boxplot(df['petal_width'],
            showmeans= True,
            color= 'yellow',
            meanprops = {
                "marker" : "+",
                "markeredgecolor" : "white",
                "markersize" : '10'
                }
            )
plt.ylabel('Width')
plt.xlabel('Petal')
plt.show()

# %%
# histplots ...
sns.histplot( df['sepal_length'],
         color= 'blue'
         )
plt.axvline(x = 5.8433 , ymin = 0, ymax = df['sepal_length'].max(),color = 'red', linestyle = 'dashed')
plt.axvline(x = 0.8253 , ymin = 0, ymax = df['sepal_length'].max(), color = 'black', linestyle = 'dashed')
plt.show()

sns.histplot( df['sepal_width'],
         color= 'green'
         )
plt.axvline(x = 3.0573 , ymin = 0, ymax = df['sepal_width'].max(),color = 'red', linestyle = 'dashed')
plt.axvline(x = 0.4344 , ymin = 0, ymax = df['sepal_width'].max(), color = 'black', linestyle = 'dashed')
plt.show()

sns.histplot( df['petal_length'],
         color= 'red'
         )
plt.axvline(x = 4.35 , ymin = 0, ymax = df['petal_length'].max(),color = 'white', linestyle = 'dashed')
plt.axvline(x = 1.7594 , ymin = 0, ymax = df['petal_length'].max(), color = 'black', linestyle = 'dashed')
plt.show()

sns.histplot( df['petal_width'],
         color= 'yellow'
         )
plt.axvline(x = 1.3 , ymin = 0, ymax = df['petal_width'].max(),color = 'red', linestyle = 'dashed')
plt.axvline(x = 0.7597 , ymin = 0, ymax = df['petal_width'].max(), color = 'black', linestyle = 'dashed')
plt.show()

# %%
# Calculating Correlation Matrix ...
from sklearn import datasets
dataset = datasets. load_iris ()  
dataframe = pd. DataFrame (data = dataset. data, columns = dataset. feature_names)  

#correlation matrix
matrix = dataframe.corr()
print(matrix)
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %% [markdown]
# # qsn 2

# %%
A_and_B = 30
A_and_notB = 20
notA_and_B = 50
notA_notB = 100
total = 200

# calculating p(A|B)
p_A_givenThat_B = (A_and_B) / (A_and_B + notA_and_B)
# calculating p(B|A)
p_B_givenThat_A = (A_and_B) / (A_and_B + A_and_notB)

print("P(A|B) = ",p_A_givenThat_B)
print("P(B|A) = ",p_B_givenThat_A)
# Out:
# P(A|B) =  0.375
# P(B|A) =  0.6

# %% [markdown]
# # qsn 3

# %%
# Given probabilities
P_Spam = 0.2
P_Not_Spam = 0.8
P_Keyword_given_Spam = 0.7
P_Keyword_given_Not_Spam = 0.1

# Calculate P(Keyword)
P_Keyword = (P_Keyword_given_Spam * P_Spam) + (P_Keyword_given_Not_Spam * P_Not_Spam)

# Calculate P(Spam|Keyword)
P_Spam_given_Keyword = (P_Keyword_given_Spam * P_Spam) / P_Keyword

# Print the result
print(f"The probability that an email is spam given that it contains the keyword is  {P_Spam_given_Keyword:.2f}")
# Out:
# The probability that an email is spam given that it contains the keyword is  0.64

# %% [markdown]
# # qsn 4

# %%
import numpy as np
import matplotlib.pyplot as plt

dataset = [5, 12, 87, 34, 56, 23, 78, 91, 45, 67]
q1 = np.quantile(dataset, 0.25)
q3 = np.quantile(dataset, 0.75)
iqr = q3 - q1

cleaned = [i for i in dataset if (q1-1.5*iqr)<=i<=(q3+1.5*iqr)]
print(cleaned)


# Sample dataset
data = [2, 3, 5, 7, 8, 9, 10, 11, 12, 15]
plt.boxplot(dataset)
plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box Plot')
plt.show()

plt.boxplot(cleaned)
plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box Plot')
plt.show()

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

# Create the first boxplot
axes[0].boxplot(dataset)
axes[0].set_title('Data 1')
axes[0].set_ylabel('Values')

# Create the second boxplot
axes[1].boxplot(cleaned)
axes[1].set_title('Data 2')

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

import matplotlib.pyplot as plt

# Sample data
# data1 = [32, 96, 45, 67, 76, 28, 79, 62, 43, 81, 70, 61, 95, 44, 60, 69, 71, 23, 69, 54, 76, 67, 82, 97, 26, 34, 18, 16, 59, 88, 29, 30, 66, 23, 65, 72, 20, 78, 49, 73, 62, 87, 37, 68, 81, 80, 77, 92, 81, 52, 43, 68, 71, 86]
# data2 = [10, 25, 30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160, 170, 180, 190, 200]

# Create subplots for side-by-side display
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

# Create the first histogram
axes[0].hist(dataset, bins=10, edgecolor='black')
axes[0].set_title('Histogram 1')
axes[0].set_xlabel('Data Values')
axes[0].set_ylabel('Frequency')

# Create the second histogram
axes[1].hist(cleaned, bins=10, edgecolor='black')
axes[1].set_title('Histogram 2')
axes[1].set_xlabel('Data Values')

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# [5, 12, 87, 34, 56, 23, 78, 91, 45, 67]
